# %%
# %matplotlib inline
import matplotlib
from matplotlib.backends.backend_pdf import PdfPages
matplotlib.rcParams.update({'font.size': 24, 'font.family':'sans-serif', 'font.sans-serif':'Arial', 'pdf.fonttype':42})
import os, glob
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.optimize import curve_fit
import scipy.optimize as opt
import matplotlib.lines as mlines
import pandas as pd
import csv
from skimage import io
with PdfPages('K:/Farinella_2024_repo/processed_data/Fig2/Fig3b.pdf') as pdf:

    fig, ax = plt.subplots(figsize = (12,10) )

    pulse_dir = np.array([660, 100, 660, 100])
    chirp_range = np.array([965, 970, 960, 960])
    # pulse_intensity = np.array([1.81e-4,1.2e-3,6.06e-3,4.19e-2])
    pulse_intensity = np.array([2.58e-4,1.7e-3,8.61e-3,5.93e-2])
    pulse_intensity = np.array([2.05e-4,1.35e-3,6.88e-3,4.74e-2])
    plt.plot([0.00008,0.2],[100,100],':',color=(0.5,0.5,0.5))

    black_set = ax.scatter(pulse_intensity,chirp_range/np.max(chirp_range)*100, color = 'black',s=50)

    ax.set_xlim(0.00008,0.2)
    ax.set_ylim(0,115)
    ax.set_xscale('log')

    ax.set_ylabel('relative scan range (%)',fontsize=28)
    ax.set_xlabel('intensity (GW/cm2)',fontsize=28)
    #################################################################
    ax.tick_params(axis='both', which='major', pad=15)


    ax.annotate("10 mW \n 660 fs", xy = (1.6e-4,chirp_range[0]/np.max(chirp_range)*100-14),fontsize=24, color='black');
    ax.annotate("1", xy = (pulse_intensity[0],chirp_range[0]/np.max(chirp_range)*100+3),fontsize=24, color='black');


    ax.annotate("10 mW \n 100 fs", xy = (1.1e-3,chirp_range[1]/np.max(chirp_range)*100-14),fontsize=24, color='black');
    ax.annotate("2", xy = (pulse_intensity[1],chirp_range[1]/np.max(chirp_range)*100+3),fontsize=24, color='black');

    ax.annotate("335 mW \n 660 fs", xy = (5.2e-3,chirp_range[2]/np.max(chirp_range)*100-14),fontsize=24, color='black');
    ax.annotate("3", xy = (pulse_intensity[2],chirp_range[2]/np.max(chirp_range)*100+3),fontsize=24, color='black');

    ax.annotate("350 mW \n 100 fs", xy = (3.6e-2,chirp_range[3]/np.max(chirp_range)*100-14),fontsize=24, color='black');
    ax.annotate("4", xy = (pulse_intensity[3],chirp_range[3]/np.max(chirp_range)*100+3),fontsize=24, color='black');
    #################################################################
    ax.tick_params('both', length=10, width=1, which='major')
    ax.tick_params('both', length=5, width=1, which='minor')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
    pdf.savefig(fig,bbox_inches='tight',pad_inches=0.05,dpi=600)  # saves the current figure into a pdf page
# Out:
# meta NOT subset; don't know how to subset; dropped
