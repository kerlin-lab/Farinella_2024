# %%
# %matplotlib inline
import os, glob
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import scipy.optimize as opt
import matplotlib.lines as mlines
import pandas as pd
import csv
from skimage import io
import matplotlib
from matplotlib.backends.backend_pdf import PdfPages
matplotlib.rcParams.update({'font.size': 32, 'font.family':'sans-serif', 'font.sans-serif':'Arial', 'pdf.fonttype':42})

uncorr_temp = np.array([28.49,28.58,28.54,28.68,28.79,28.88,28.96])
uncorr_baseline_temp = np.array([28.54,28.47,28.47,28.51,28.59,28.53,28.52])

corr_temp = np.array([29.71,29.7,29.67,29.68,29.67,29.71,29.71])
corr_baseline_temp = np.array([29.71,29.63,29.63,29.46,29.67,29.77,29.76])
power = np.array([50,100,150,200,250,300,350])

fig, ax = plt.subplots(figsize = (12,10) )

black_set = ax.plot(power,uncorr_temp-uncorr_baseline_temp,'.-', color = (0,0,0),markersize=25,linewidth=2.5,label='factory')
red_set = ax.plot(power,corr_temp-corr_baseline_temp, '.-',color = (1,0,0),markersize=25,linewidth=2.5,label='optimized')


ax.set_ylabel('deviation from baseline (C)',fontsize=34)
ax.set_xlabel('average laser power (mW)',fontsize=34)


ax.axhline(y = 0, color='gray',linestyle='dashed')
ax.set_ylim([-0.1,0.5])
ax.legend(fontsize = 24,loc=2)
#################################################################
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()
with PdfPages('K:/Farinella_2024_repo/processed_data/Fig2/Fig2d.pdf') as pdf:
    pdf.savefig(fig,bbox_inches='tight',pad_inches=0.05,dpi=600)  # saves the current figure into a pdf page
# Out:
# meta NOT subset; don't know how to subset; dropped
