# %%
# %matplotlib inline
import matplotlib
from matplotlib.backends.backend_pdf import PdfPages
matplotlib.rcParams.update({'font.size': 20, 'font.family':'sans-serif', 'font.sans-serif':'Arial', 'pdf.fonttype':42})
import os, glob
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.optimize import curve_fit
import scipy.optimize as opt
import matplotlib.lines as mlines
import pandas as pd
import csv
from skimage import io
from matplotlib.gridspec import GridSpec


corr_dir = 'K:/Farinella_2024_repo/raw_data/Fig2/Temp_Correction_Scanning/'


sr_50mW  = io.imread(corr_dir+'50mW_31.04C_270Vpp_218V.tif')
sr_100mW = io.imread(corr_dir+'100mW_30.96C_270Vpp_218V.tif')
sr_150mW = io.imread(corr_dir+'150mW_30.84C_270Vpp_218V.tif')
sr_200mW = io.imread(corr_dir+'200mW_30.76C_270Vpp_218V.tif')
sr_250mW = io.imread(corr_dir+'250mW_30.7C_270Vpp_218V.tif')
sr_300mW = io.imread(corr_dir+'300mW_30.58C_270Vpp_218V.tif')
sr_350mW = io.imread(corr_dir+'350mW_30.48C_270Vpp_218V.tif')
with PdfPages('K:/Farinella_2024_repo/processed_data/Fig2/Fig2c.pdf') as pdf:

    fig = plt.figure(figsize=(20, 20))

    gs = fig.add_gridspec(nrows=100, ncols = 700)

    colormap = 'gray'
    anno_color = 'black'
    anno_fontsize = 20
    spinecolor = 'white'
    anno_x_offset = 0.4
    face_color = 'white'
    ylim = [130,1320]
    xlim = [712,788]
    grid_width = 50

    ax0 = fig.add_subplot(gs[0:100, grid_width*0:grid_width*1])
    h = ax0.imshow(np.transpose(sr_50mW), cmap=colormap,interpolation='none')
    ax0.set_xlim(xlim)
    ax0.set_ylim(ylim)
    ax0.set_aspect('equal')
    ax0.set_xticks([])
    ax0.set_yticks([])

    ax1 = fig.add_subplot(gs[0:100, grid_width*1:grid_width*2])
    h = ax1.imshow(np.transpose(sr_100mW), cmap=colormap,interpolation='none')
    ax1.set_xlim(xlim)
    ax1.set_ylim(ylim)
    ax1.set_aspect('equal')
    ax1.set_xticks([])
    ax1.set_yticks([])

    ax2 = fig.add_subplot(gs[0:100, grid_width*2:grid_width*3])
    h = ax2.imshow(np.transpose(sr_150mW), cmap=colormap,interpolation='none')
    ax2.set_xlim(xlim)
    ax2.set_ylim(ylim)
    ax2.set_aspect('equal')
    ax2.set_xticks([])
    ax2.set_yticks([])

    ax3 = fig.add_subplot(gs[0:100, grid_width*3:grid_width*4])
    h = ax3.imshow(np.transpose(sr_200mW), cmap=colormap,interpolation='none')
    ax3.set_xlim(xlim)
    ax3.set_ylim(ylim)
    ax3.set_aspect('equal')
    ax3.set_xticks([])
    ax3.set_yticks([])

    ax4 = fig.add_subplot(gs[0:100, grid_width*4:grid_width*5])
    h = ax4.imshow(np.transpose(sr_250mW), cmap=colormap,interpolation='none')
    ax4.set_xlim(xlim)
    ax4.set_ylim(ylim)
    ax4.set_aspect('equal')
    ax4.set_xticks([])
    ax4.set_yticks([])

    ax5 = fig.add_subplot(gs[0:100, grid_width*5:grid_width*6])
    h = ax5.imshow(np.transpose(sr_300mW), cmap=colormap,interpolation='none')
    ax5.set_xlim(xlim)
    ax5.set_ylim(ylim)
    ax5.set_aspect('equal')
    ax5.set_xticks([])
    ax5.set_yticks([])

    ax6 = fig.add_subplot(gs[0:100, grid_width*6:grid_width*7])
    h = ax6.imshow(np.transpose(sr_350mW), cmap=colormap,interpolation='none')
    ax6.set_xlim(xlim)
    ax6.set_ylim(ylim)
    ax6.set_aspect('equal')
    ax6.set_xticks([])
    ax6.set_yticks([])

    pdf.savefig(fig,bbox_inches='tight',pad_inches=0.05,dpi=600)  # saves the current figure into a pdf page
